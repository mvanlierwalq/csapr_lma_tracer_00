# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Random-preamble-stuff" data-toc-modified-id="Random-preamble-stuff-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Random preamble stuff</a></span></li><li><span><a href="#C-SAPR-data-download" data-toc-modified-id="C-SAPR-data-download-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>C-SAPR data download</a></span></li><li><span><a href="#Process-C-SAPR-data-(phase)" data-toc-modified-id="Process-C-SAPR-data-(phase)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Process C-SAPR data (phase)</a></span></li><li><span><a href="#Plot-figures,-including-NEXRAD-thing" data-toc-modified-id="Plot-figures,-including-NEXRAD-thing-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Plot figures, including NEXRAD thing</a></span><ul class="toc-item"><li><span><a href="#Do-main-plots-(run-this-after-4.2)" data-toc-modified-id="Do-main-plots-(run-this-after-4.2)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Do main plots (run this after 4.2)</a></span></li><li><span><a href="#Download-NEXRAD-(run-this-before-4.1)" data-toc-modified-id="Download-NEXRAD-(run-this-before-4.1)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Download NEXRAD (run this before 4.1)</a></span></li></ul></li><li><span><a href="#Load-lightning-to-plot-with-RHIs-(incomplete)" data-toc-modified-id="Load-lightning-to-plot-with-RHIs-(incomplete)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Load lightning to plot with RHIs (incomplete)</a></span></li></ul></div>

# %%
import glob
import os
from pathlib import Path
import act
import imageio as imageio
import matplotlib
import matplotlib.pyplot as plt
import pyart
from copy import deepcopy
import numpy as np
import cartopy.crs as ccrs
import shapely
import pyart
from tint.data_utils import get_nexrad_keys, read_nexrad_key
from tint import Cell_tracks, animate
from tint.visualization import embed_mp4_as_gif
import pandas as pd
from csu_radartools import (csu_fhc, csu_liquid_ice_mass, csu_blended_rain,csu_dsd, csu_kdp, csu_misc)
import warnings
import matplotlib.cm as cm
import pyart.graph.cm as pcm
from lmatools.io.LMA_h5_file import LMAh5File
from lmatools.coordinateSystems import RadarCoordinateSystem, GeographicSystem, TangentPlaneCartesianSystem, MapProjection
from dualpol import DualPolRetrieval # https://github.com/nasa/DualPol
from netCDF4 import Dataset
from pyproj import Geod
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %% [markdown]
# ## Random preamble stuff

# %%
plt.rcParams['font.size'] = 14

# %%
import matplotlib.gridspec as gridspec

# %%
#define walkspace function
def walklevel(some_dir, level=1):
    some_dir = some_dir.rstrip(os.path.sep)
    assert os.path.isdir(some_dir)
    num_sep = some_dir.count(os.path.sep)
    for root, dirs, files in os.walk(some_dir):
        yield root, dirs, files
        num_sep_this = root.count(os.path.sep)
        if num_sep + level <= num_sep_this:
            #print('hello!')
            del dirs[:]

# %% [markdown]
# ## C-SAPR data download

# %%
act.discovery.download_data?

# %%
username = "mvanlierwalq"
token   = "5b70d23c96777b14"

datastream = "houcsapr2cfrS2.a1"

#start_date = "2022-06-04T21:00:00"
#end_date   = "2022-06-04T21:20:00"
startdate = "2022-06-17T19:00:00"
enddate   = "2022-06-17T23:00:00"

# %%
#..Download a single time
#startdate = "2022-06-02T21:07:00"
#enddate = "2022-06-02T21:08:00"
startdate = "2022-06-04T19:00:00"
enddate = "2022-06-04T23:00:00"
june4_csapr_files = act.discovery.download_data(username,token,datastream,
                                                    startdate,enddate,time='210735')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-991aef0849ac> in <module>
#       5 enddate = "2022-06-04T23:00:00"
#       6 june4_csapr_files = act.discovery.download_data(username,token,datastream,
# ----> 7                                                     startdate,enddate,time='210735')
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/act/discovery/get_armfiles.py in download_data(username, token, datastream, startdate, enddate, time, output)
#      93     # if the arguments were provided
#      94     if startdate:
# ---> 95         start = date_parser(startdate, output_format='%Y-%m-%d')
#      96         start = f'&start={startdate}'
#      97     if enddate:
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/act/utils/datetime_utils.py in date_parser(date_string, output_format, return_datetime)
#     207     raise ValueError(
#     208         'Invalid Date format, please use one of these formats '
# --> 209         + fmt_strings)
#
# ValueError: Invalid Date format, please use one of these formats %Y-%m-%d, %d.%m.%Y, %d/%m/%Y, %Y%m%d, %Y/%m/%d

# %%
#..approximate metling level
melt_0604 = 4400/1000.
melt_0617 = 4830/1000.

# %%
#..Downlaod CSAPR data or just load in pre-existing filenames
brand_new = False
if brand_new:
    june17_csapr_files = act.discovery.download_data(username,token,datastream,
                                                    startdate,enddate)
else:
    basepath = './houcsapr2cfrS2.a1/'
    #basepath = '/home/marcus/marcus_data/ASR_TRACER_data/houscsapr2cfrS2_0604/'
    numfiles = 0
    filepre = 'houcsapr'
    june17_csapr_files = []
    for root,dirs,files in walklevel(basepath,level=1):
        for file in files:
            if file.startswith(filepre): #change start with as string
                june17_csapr_files.append(file)
                numfiles += 1
june17_csapr_files = sorted(june17_csapr_files)
print(numfiles)
# Out:
# 757

# %%
numfiles = len(june17_csapr_files)

# %%
# !mkdir quicklooks/rhi
# !mkdir quicklooks/ppi
# !mkdir quicklooks/vpt

# %%
#..Plot quicklooks of CSAPR
for file in june17_csapr_files:
    radar = pyart.io.read(file)
    #print(radar.scan_type)
    #print(file)
    if (radar.scan_type != 'other' and radar.scan_type != 'sector'):
        fig = plt.figure(figsize=(6, 4))
        ax = fig.add_subplot(111)
        display = pyart.graph.RadarDisplay(radar)
        display.plot("reflectivity", 0)
        fig.savefig(f"quicklooks/{radar.scan_type}/{Path(file).stem}.png", dpi=200)
        plt.close(fig)
        fig.clf()
    else:
        print('skipping:', file[-15:], ', type = ',radar.scan_type)
# Out:
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190001.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190106.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190154.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190246.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190334.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190424.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190511.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190615.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190705.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190754.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190844.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190935.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191026.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191117.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191204.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191251.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191401.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191630.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191755.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191918.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192043.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192208.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192336.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192507.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192639.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192805.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192948.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193114.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193240.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193408.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193535.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193706.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193834.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193959.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194135.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194311.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194449.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194620.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194755.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194925.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195056.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195226.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195353.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195521.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195649.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195857.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200007.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200051.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200134.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200217.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200305.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200348.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200431.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200522.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200608.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200659.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200743.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200829.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200915.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200956.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201053.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201139.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201424.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201625.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201827.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202025.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202231.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202430.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202631.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202830.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203031.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203229.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203430.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203630.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203831.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204032.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204233.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204431.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204631.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204825.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205027.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205221.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205420.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205622.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205751.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205919.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210045.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210210.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210335.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210459.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210625.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210751.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210920.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211047.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211208.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211335.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211501.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211632.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211801.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211931.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212106.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212235.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212410.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212540.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212715.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212844.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213009.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213139.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213305.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213434.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213559.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213734.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213910.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214043.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214214.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214340.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214511.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214640.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214824.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215009.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215134.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215259.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215425.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215550.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215715.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215840.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220004.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220130.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220255.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220418.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220545.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220710.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220834.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220959.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221127.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221250.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221415.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221538.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221704.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221829.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221954.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222122.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222244.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222411.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222539.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222706.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222829.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222956.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223120.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223245.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223410.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223535.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223659.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223824.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223950.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224115.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224246.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224415.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224552.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224720.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224845.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225011.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225134.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225259.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225424.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225556.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225726.nc , type =  sector
# skipping: /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225856.nc , type =  sector

# %%
for i in range(numfiles):
    if not brand_new:
        june17_csapr_files[i] = basepath+june17_csapr_files[i]
    print(i,june17_csapr_files[i])
# Out:
# 0 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190001.nc
# 1 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190027.nc
# 2 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190041.nc
# 3 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190057.nc
# 4 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190106.nc
# 5 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190132.nc
# 6 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190145.nc
# 7 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190154.nc
# 8 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190219.nc
# 9 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190237.nc
# 10 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190246.nc
# 11 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190312.nc
# 12 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190325.nc
# 13 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190334.nc
# 14 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190358.nc
# 15 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190414.nc
# 16 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190424.nc
# 17 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190448.nc
# 18 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190502.nc
# 19 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190511.nc
# 20 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190536.nc
# 21 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190553.nc
# 22 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190606.nc
# 23 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190615.nc
# 24 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190641.nc
# 25 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190656.nc
# 26 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190705.nc
# 27 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190730.nc
# 28 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190746.nc
# 29 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190754.nc
# 30 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190821.nc
# 31 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190835.nc
# 32 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190844.nc
# 33 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190909.nc
# 34 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190926.nc
# 35 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.190935.nc
# 36 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191001.nc
# 37 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191016.nc
# 38 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191026.nc
# 39 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191052.nc
# 40 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191108.nc
# 41 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191117.nc
# 42 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191143.nc
# 43 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191155.nc
# 44 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191204.nc
# 45 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191229.nc
# 46 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191242.nc
# 47 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191251.nc
# 48 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191316.nc
# 49 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191328.nc
# 50 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191345.nc
# 51 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191401.nc
# 52 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191531.nc
# 53 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191545.nc
# 54 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191602.nc
# 55 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191616.nc
# 56 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191630.nc
# 57 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191655.nc
# 58 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191711.nc
# 59 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191727.nc
# 60 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191740.nc
# 61 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191755.nc
# 62 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191820.nc
# 63 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191835.nc
# 64 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191850.nc
# 65 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191906.nc
# 66 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191918.nc
# 67 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.191943.nc
# 68 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192000.nc
# 69 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192016.nc
# 70 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192031.nc
# 71 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192043.nc
# 72 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192108.nc
# 73 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192124.nc
# 74 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192141.nc
# 75 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192155.nc
# 76 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192208.nc
# 77 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192233.nc
# 78 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192251.nc
# 79 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192306.nc
# 80 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192320.nc
# 81 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192336.nc
# 82 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192401.nc
# 83 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192415.nc
# 84 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192431.nc
# 85 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192446.nc
# 86 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192507.nc
# 87 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192534.nc
# 88 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192550.nc
# 89 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192608.nc
# 90 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192625.nc
# 91 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192639.nc
# 92 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192707.nc
# 93 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192721.nc
# 94 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192737.nc
# 95 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192751.nc
# 96 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192805.nc
# 97 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192833.nc
# 98 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192852.nc
# 99 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192912.nc
# 100 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192932.nc
# 101 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.192948.nc
# 102 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193017.nc
# 103 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193032.nc
# 104 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193046.nc
# 105 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193102.nc
# 106 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193114.nc
# 107 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193142.nc
# 108 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193156.nc
# 109 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193212.nc
# 110 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193226.nc
# 111 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193240.nc
# 112 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193308.nc
# 113 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193326.nc
# 114 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193340.nc
# 115 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193356.nc
# 116 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193408.nc
# 117 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193435.nc
# 118 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193451.nc
# 119 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193506.nc
# 120 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193522.nc
# 121 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193535.nc
# 122 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193603.nc
# 123 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193621.nc
# 124 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193636.nc
# 125 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193651.nc
# 126 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193706.nc
# 127 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193734.nc
# 128 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193752.nc
# 129 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193806.nc
# 130 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193822.nc
# 131 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193834.nc
# 132 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193902.nc
# 133 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193916.nc
# 134 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193932.nc
# 135 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193946.nc
# 136 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.193959.nc
# 137 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194027.nc
# 138 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194047.nc
# 139 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194104.nc
# 140 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194121.nc
# 141 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194135.nc
# 142 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194202.nc
# 143 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194221.nc
# 144 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194239.nc
# 145 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194257.nc
# 146 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194311.nc
# 147 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194339.nc
# 148 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194358.nc
# 149 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194415.nc
# 150 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194433.nc
# 151 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194449.nc
# 152 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194518.nc
# 153 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194537.nc
# 154 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194551.nc
# 155 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194605.nc
# 156 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194620.nc
# 157 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194648.nc
# 158 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194705.nc
# 159 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194723.nc
# 160 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194740.nc
# 161 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194755.nc
# 162 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194824.nc
# 163 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194841.nc
# 164 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194856.nc
# 165 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194910.nc
# 166 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194925.nc
# 167 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.194954.nc
# 168 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195010.nc
# 169 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195028.nc
# 170 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195043.nc
# 171 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195056.nc
# 172 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195124.nc
# 173 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195141.nc
# 174 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195157.nc
# 175 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195212.nc
# 176 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195226.nc
# 177 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195254.nc
# 178 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195311.nc
# 179 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195327.nc
# 180 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195341.nc
# 181 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195353.nc
# 182 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195421.nc
# 183 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195437.nc
# 184 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195452.nc
# 185 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195507.nc
# 186 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195521.nc
# 187 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195550.nc
# 188 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195607.nc
# 189 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195621.nc
# 190 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195636.nc
# 191 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195649.nc
# 192 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195714.nc
# 193 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195731.nc
# 194 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195857.nc
# 195 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.195926.nc
# 196 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200007.nc
# 197 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200036.nc
# 198 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200051.nc
# 199 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200117.nc
# 200 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200134.nc
# 201 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200203.nc
# 202 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200217.nc
# 203 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200245.nc
# 204 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200305.nc
# 205 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200333.nc
# 206 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200348.nc
# 207 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200417.nc
# 208 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200431.nc
# 209 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200459.nc
# 210 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200522.nc
# 211 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200551.nc
# 212 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200608.nc
# 213 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200637.nc
# 214 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200659.nc
# 215 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200728.nc
# 216 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200743.nc
# 217 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200812.nc
# 218 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200829.nc
# 219 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200858.nc
# 220 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200915.nc
# 221 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200944.nc
# 222 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.200956.nc
# 223 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201025.nc
# 224 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201053.nc
# 225 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201122.nc
# 226 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201139.nc
# 227 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201208.nc
# 228 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201424.nc
# 229 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201505.nc
# 230 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201528.nc
# 231 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201548.nc
# 232 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201607.nc
# 233 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201625.nc
# 234 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201707.nc
# 235 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201729.nc
# 236 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201749.nc
# 237 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201808.nc
# 238 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201827.nc
# 239 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201908.nc
# 240 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201928.nc
# 241 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201947.nc
# 242 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202007.nc
# 243 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202025.nc
# 244 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202107.nc
# 245 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202130.nc
# 246 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202152.nc
# 247 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202213.nc
# 248 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202231.nc
# 249 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202312.nc
# 250 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202333.nc
# 251 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202353.nc
# 252 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202411.nc
# 253 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202430.nc
# 254 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202511.nc
# 255 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202534.nc
# 256 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202555.nc
# 257 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202612.nc
# 258 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202631.nc
# 259 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202711.nc
# 260 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202733.nc
# 261 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202755.nc
# 262 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202813.nc
# 263 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202830.nc
# 264 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202911.nc
# 265 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202932.nc
# 266 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.202953.nc
# 267 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203012.nc
# 268 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203031.nc
# 269 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203113.nc
# 270 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203135.nc
# 271 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203152.nc
# 272 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203212.nc
# 273 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203229.nc
# 274 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203311.nc
# 275 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203331.nc
# 276 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203352.nc
# 277 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203414.nc
# 278 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203430.nc
# 279 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203511.nc
# 280 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203531.nc
# 281 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203552.nc
# 282 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203612.nc
# 283 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203630.nc
# 284 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203711.nc
# 285 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203732.nc
# 286 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203753.nc
# 287 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203812.nc
# 288 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203831.nc
# 289 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203912.nc
# 290 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203932.nc
# 291 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.203953.nc
# 292 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204014.nc
# 293 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204032.nc
# 294 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204113.nc
# 295 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204133.nc
# 296 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204153.nc
# 297 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204213.nc
# 298 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204233.nc
# 299 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204314.nc
# 300 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204333.nc
# 301 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204353.nc
# 302 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204412.nc
# 303 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204431.nc
# 304 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204512.nc
# 305 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204532.nc
# 306 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204553.nc
# 307 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204612.nc
# 308 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204631.nc
# 309 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204706.nc
# 310 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204727.nc
# 311 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204747.nc
# 312 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204807.nc
# 313 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204825.nc
# 314 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204906.nc
# 315 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204928.nc
# 316 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.204949.nc
# 317 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205008.nc
# 318 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205027.nc
# 319 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205102.nc
# 320 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205122.nc
# 321 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205143.nc
# 322 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205202.nc
# 323 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205221.nc
# 324 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205302.nc
# 325 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205324.nc
# 326 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205343.nc
# 327 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205403.nc
# 328 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205420.nc
# 329 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205501.nc
# 330 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205524.nc
# 331 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205543.nc
# 332 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205602.nc
# 333 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205622.nc
# 334 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205651.nc
# 335 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205707.nc
# 336 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205721.nc
# 337 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205736.nc
# 338 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205751.nc
# 339 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205820.nc
# 340 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205836.nc
# 341 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205850.nc
# 342 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205906.nc
# 343 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205919.nc
# 344 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.205944.nc
# 345 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210001.nc
# 346 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210015.nc
# 347 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210031.nc
# 348 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210045.nc
# 349 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210110.nc
# 350 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210125.nc
# 351 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210141.nc
# 352 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210155.nc
# 353 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210210.nc
# 354 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210235.nc
# 355 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210252.nc
# 356 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210305.nc
# 357 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210321.nc
# 358 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210335.nc
# 359 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210400.nc
# 360 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210415.nc
# 361 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210431.nc
# 362 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210446.nc
# 363 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210459.nc
# 364 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210524.nc
# 365 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210543.nc
# 366 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210554.nc
# 367 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210612.nc
# 368 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210625.nc
# 369 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210650.nc
# 370 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210706.nc
# 371 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210721.nc
# 372 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210734.nc
# 373 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210751.nc
# 374 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210816.nc
# 375 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210834.nc
# 376 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210850.nc
# 377 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210907.nc
# 378 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210920.nc
# 379 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.210945.nc
# 380 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211002.nc
# 381 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211018.nc
# 382 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211031.nc
# 383 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211047.nc
# 384 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211112.nc
# 385 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211126.nc
# 386 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211142.nc
# 387 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211157.nc
# 388 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211208.nc
# 389 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211234.nc
# 390 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211249.nc
# 391 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211306.nc
# 392 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211321.nc
# 393 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211335.nc
# 394 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211400.nc
# 395 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211416.nc
# 396 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211430.nc
# 397 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211446.nc
# 398 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211501.nc
# 399 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211532.nc
# 400 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211547.nc
# 401 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211601.nc
# 402 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211617.nc
# 403 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211632.nc
# 404 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211701.nc
# 405 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211717.nc
# 406 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211731.nc
# 407 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211745.nc
# 408 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211801.nc
# 409 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211831.nc
# 410 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211848.nc
# 411 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211903.nc
# 412 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211917.nc
# 413 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.211931.nc
# 414 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212002.nc
# 415 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212017.nc
# 416 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212033.nc
# 417 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212049.nc
# 418 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212106.nc
# 419 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212137.nc
# 420 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212152.nc
# 421 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212208.nc
# 422 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212221.nc
# 423 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212235.nc
# 424 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212302.nc
# 425 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212322.nc
# 426 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212336.nc
# 427 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212354.nc
# 428 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212410.nc
# 429 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212437.nc
# 430 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212451.nc
# 431 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212506.nc
# 432 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212522.nc
# 433 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212540.nc
# 434 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212608.nc
# 435 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212627.nc
# 436 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212641.nc
# 437 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212657.nc
# 438 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212715.nc
# 439 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212743.nc
# 440 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212801.nc
# 441 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212816.nc
# 442 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212832.nc
# 443 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212844.nc
# 444 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212911.nc
# 445 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212927.nc
# 446 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212941.nc
# 447 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.212956.nc
# 448 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213009.nc
# 449 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213036.nc
# 450 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213050.nc
# 451 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213107.nc
# 452 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213126.nc
# 453 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213139.nc
# 454 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213207.nc
# 455 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213221.nc
# 456 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213236.nc
# 457 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213252.nc
# 458 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213305.nc
# 459 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213332.nc
# 460 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213348.nc
# 461 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213406.nc
# 462 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213421.nc
# 463 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213434.nc
# 464 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213501.nc
# 465 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213517.nc
# 466 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213531.nc
# 467 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213546.nc
# 468 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213559.nc
# 469 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213627.nc
# 470 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213642.nc
# 471 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213702.nc
# 472 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213717.nc
# 473 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213734.nc
# 474 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213802.nc
# 475 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213822.nc
# 476 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213840.nc
# 477 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213856.nc
# 478 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213910.nc
# 479 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213938.nc
# 480 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.213957.nc
# 481 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214011.nc
# 482 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214028.nc
# 483 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214043.nc
# 484 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214111.nc
# 485 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214126.nc
# 486 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214141.nc
# 487 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214158.nc
# 488 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214214.nc
# 489 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214241.nc
# 490 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214256.nc
# 491 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214310.nc
# 492 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214326.nc
# 493 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214340.nc
# 494 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214411.nc
# 495 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214427.nc
# 496 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214442.nc
# 497 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214457.nc
# 498 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214511.nc
# 499 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214542.nc
# 500 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214557.nc
# 501 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214611.nc
# 502 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214628.nc
# 503 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214640.nc
# 504 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214712.nc
# 505 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214732.nc
# 506 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214751.nc
# 507 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214808.nc
# 508 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214824.nc
# 509 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214855.nc
# 510 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214912.nc
# 511 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214931.nc
# 512 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.214947.nc
# 513 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215009.nc
# 514 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215034.nc
# 515 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215051.nc
# 516 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215104.nc
# 517 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215121.nc
# 518 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215134.nc
# 519 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215159.nc
# 520 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215216.nc
# 521 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215231.nc
# 522 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215246.nc
# 523 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215259.nc
# 524 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215324.nc
# 525 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215341.nc
# 526 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215356.nc
# 527 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215411.nc
# 528 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215425.nc
# 529 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215450.nc
# 530 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215506.nc
# 531 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215521.nc
# 532 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215534.nc
# 533 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215550.nc
# 534 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215615.nc
# 535 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215631.nc
# 536 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215647.nc
# 537 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215700.nc
# 538 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215715.nc
# 539 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215740.nc
# 540 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215756.nc
# 541 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215809.nc
# 542 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215825.nc
# 543 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215840.nc
# 544 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215905.nc
# 545 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215921.nc
# 546 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215936.nc
# 547 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.215951.nc
# 548 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220004.nc
# 549 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220030.nc
# 550 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220046.nc
# 551 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220100.nc
# 552 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220115.nc
# 553 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220130.nc
# 554 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220156.nc
# 555 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220210.nc
# 556 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220226.nc
# 557 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220241.nc
# 558 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220255.nc
# 559 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220320.nc
# 560 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220337.nc
# 561 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220351.nc
# 562 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220405.nc
# 563 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220418.nc
# 564 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220444.nc
# 565 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220459.nc
# 566 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220516.nc
# 567 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220532.nc
# 568 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220545.nc
# 569 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220610.nc
# 570 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220626.nc
# 571 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220641.nc
# 572 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220654.nc
# 573 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220710.nc
# 574 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220735.nc
# 575 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220752.nc
# 576 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220805.nc
# 577 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220820.nc
# 578 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220834.nc
# 579 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220900.nc
# 580 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220914.nc
# 581 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220932.nc
# 582 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220945.nc
# 583 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.220959.nc
# 584 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221024.nc
# 585 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221040.nc
# 586 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221057.nc
# 587 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221111.nc
# 588 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221127.nc
# 589 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221152.nc
# 590 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221206.nc
# 591 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221219.nc
# 592 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221235.nc
# 593 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221250.nc
# 594 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221315.nc
# 595 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221330.nc
# 596 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221346.nc
# 597 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221400.nc
# 598 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221415.nc
# 599 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221440.nc
# 600 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221455.nc
# 601 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221511.nc
# 602 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221527.nc
# 603 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221538.nc
# 604 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221603.nc
# 605 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221620.nc
# 606 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221637.nc
# 607 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221651.nc
# 608 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221704.nc
# 609 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221729.nc
# 610 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221746.nc
# 611 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221759.nc
# 612 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221818.nc
# 613 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221829.nc
# 614 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221854.nc
# 615 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221910.nc
# 616 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221925.nc
# 617 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221942.nc
# 618 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.221954.nc
# 619 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222019.nc
# 620 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222034.nc
# 621 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222052.nc
# 622 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222106.nc
# 623 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222122.nc
# 624 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222147.nc
# 625 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222201.nc
# 626 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222215.nc
# 627 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222230.nc
# 628 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222244.nc
# 629 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222309.nc
# 630 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222324.nc
# 631 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222342.nc
# 632 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222355.nc
# 633 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222411.nc
# 634 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222436.nc
# 635 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222450.nc
# 636 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222507.nc
# 637 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222521.nc
# 638 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222539.nc
# 639 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222605.nc
# 640 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222620.nc
# 641 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222636.nc
# 642 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222651.nc
# 643 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222706.nc
# 644 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222732.nc
# 645 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222745.nc
# 646 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222801.nc
# 647 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222815.nc
# 648 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222829.nc
# 649 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222855.nc
# 650 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222910.nc
# 651 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222926.nc
# 652 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222941.nc
# 653 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.222956.nc
# 654 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223022.nc
# 655 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223036.nc
# 656 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223049.nc
# 657 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223106.nc
# 658 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223120.nc
# 659 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223146.nc
# 660 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223201.nc
# 661 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223215.nc
# 662 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223232.nc
# 663 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223245.nc
# 664 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223310.nc
# 665 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223326.nc
# 666 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223340.nc
# 667 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223355.nc
# 668 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223410.nc
# 669 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223435.nc
# 670 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223452.nc
# 671 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223506.nc
# 672 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223519.nc
# 673 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223535.nc
# 674 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223600.nc
# 675 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223617.nc
# 676 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223630.nc
# 677 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223645.nc
# 678 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223659.nc
# 679 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223725.nc
# 680 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223742.nc
# 681 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223755.nc
# 682 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223810.nc
# 683 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223824.nc
# 684 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223850.nc
# 685 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223907.nc
# 686 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223921.nc
# 687 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223935.nc
# 688 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.223950.nc
# 689 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224015.nc
# 690 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224029.nc
# 691 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224046.nc
# 692 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224101.nc
# 693 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224115.nc
# 694 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224144.nc
# 695 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224201.nc
# 696 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224215.nc
# 697 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224231.nc
# 698 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224246.nc
# 699 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224315.nc
# 700 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224330.nc
# 701 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224347.nc
# 702 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224401.nc
# 703 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224415.nc
# 704 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224446.nc
# 705 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224503.nc
# 706 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224519.nc
# 707 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224538.nc
# 708 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224552.nc
# 709 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224623.nc
# 710 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224638.nc
# 711 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224652.nc
# 712 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224707.nc
# 713 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224720.nc
# 714 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224745.nc
# 715 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224801.nc
# 716 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224816.nc
# 717 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224833.nc
# 718 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224845.nc
# 719 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224911.nc
# 720 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224925.nc
# 721 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224942.nc
# 722 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.224955.nc
# 723 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225011.nc
# 724 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225036.nc
# 725 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225050.nc
# 726 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225106.nc
# 727 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225123.nc
# 728 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225134.nc
# 729 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225159.nc
# 730 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225218.nc
# 731 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225232.nc
# 732 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225246.nc
# 733 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225259.nc
# 734 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225325.nc
# 735 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225342.nc
# 736 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225355.nc
# 737 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225411.nc
# 738 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225424.nc
# 739 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225454.nc
# 740 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225512.nc
# 741 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225527.nc
# 742 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225541.nc
# 743 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225556.nc
# 744 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225626.nc
# 745 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225643.nc
# 746 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225656.nc
# 747 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225711.nc
# 748 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225726.nc
# 749 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225755.nc
# 750 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225810.nc
# 751 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225825.nc
# 752 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225841.nc
# 753 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225856.nc
# 754 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225925.nc
# 755 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225942.nc
# 756 ./houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.225956.nc

# %%
#..Hand selected "sets" of RHIs named by (arbitrary) index in my directory. Original
#..integers refer to listing if you follow above directions for download of CSAPR
# offset = (1193-235)
# csapr_idx1 = [1194-offset,1196-offset,1199-offset,1200-offset,1201-offset,1204-offset,
#               1205-offset,1206-offset,1213-offset,1223-offset]
# csapr_idx2 = [1209-offset,1210-offset,1214-offset,1215-offset,1216-offset,1219-offset]
# csapr_idx3 = [393,]
csapr_idx1 = [229,230,234,235,236,237,240,242,244,246,247,249,251,252,254,256,259,261,266,271]

# %%
print(csapr_idx1)
# Out:
# [235, 236, 237238, 240, 242, 244, 246, 247, 249, 251, 252, 254, 256, 259, 261, 266, 271]

# %%
basepath = './houcsapr2cfrS2.a1/'

# %%
print(june17_csapr_files[240][-36:])
# Out:
# houcsapr2cfrS2.a1.20220617.201928.nc

# %% [markdown]
# ## Process C-SAPR data (phase)

# %%
#..Process all data specified by index for downloaded files
testpath = './csapr_test_0617/'
ii = 0
if brand_new:
    for idx in csapr_idx1:
        fname = june17_csapr_files[idx][-36:]
        radar = pyart.io.read(basepath+fname)
        retrieve = DualPolRetrieval(radar, gs=100.0, dz='reflectivity',
                              dr='differential_reflectivity',
                              #dr='RD',
                              dp='differential_phase',
                              rh='copol_correlation_coeff',
                              #fhc_T_factor=2, ice_flag=True,
                              #fhc_flag=False, ice_flag=False,dsd_flag=False,precip_flag=False,liquid_ice_flag=False,
                              fhc_flag=True, ice_flag=False,dsd_flag=True,precip_flag=True,liquid_ice_flag=False,
                              kdp_window=1.8, thresh_sdp=20.0, speckle=3,
                              #kdp_window=5, thresh_sdp=20.0, speckle=3,   #..prev
                              #kdp_window=5, thresh_sdp=20.0, speckle=10,
                              kdp_method='CSU',
                              rain_method='hidro',
                              qc_flag=True, verbose=False)
        print(testpath+fname[:-3] + '_proc.nc')
        pyart.io.write_cfradial(testpath+fname[:-3]+'_proc.nc', radar)
        ii += 1
else:
    pass

# %%
print(june4_csapr_files)
# Out:
# ['houcsapr2cfrS2.a1.20220604.125221.nc', 'houcsapr2cfrS2.a1.20220604.125451.nc', 'houcsapr2cfrS2.a1.20220604.130438.nc', 'houcsapr2cfrS2.a1.20220604.130522.nc', 'houcsapr2cfrS2.a1.20220604.130638.nc', 'houcsapr2cfrS2.a1.20220604.130739.nc', 'houcsapr2cfrS2.a1.20220604.130949.nc', 'houcsapr2cfrS2.a1.20220604.131018.nc', 'houcsapr2cfrS2.a1.20220604.131035.nc', 'houcsapr2cfrS2.a1.20220604.131103.nc', 'houcsapr2cfrS2.a1.20220604.131118.nc', 'houcsapr2cfrS2.a1.20220604.131315.nc', 'houcsapr2cfrS2.a1.20220604.131518.nc', 'houcsapr2cfrS2.a1.20220604.131619.nc', 'houcsapr2cfrS2.a1.20220604.200008.nc', 'houcsapr2cfrS2.a1.20220604.200037.nc', 'houcsapr2cfrS2.a1.20220604.200053.nc', 'houcsapr2cfrS2.a1.20220604.200109.nc', 'houcsapr2cfrS2.a1.20220604.200124.nc', 'houcsapr2cfrS2.a1.20220604.200138.nc', 'houcsapr2cfrS2.a1.20220604.200208.nc', 'houcsapr2cfrS2.a1.20220604.200225.nc', 'houcsapr2cfrS2.a1.20220604.200238.nc', 'houcsapr2cfrS2.a1.20220604.200254.nc', 'houcsapr2cfrS2.a1.20220604.200307.nc', 'houcsapr2cfrS2.a1.20220604.200337.nc', 'houcsapr2cfrS2.a1.20220604.200353.nc', 'houcsapr2cfrS2.a1.20220604.200409.nc', 'houcsapr2cfrS2.a1.20220604.200425.nc', 'houcsapr2cfrS2.a1.20220604.200438.nc', 'houcsapr2cfrS2.a1.20220604.200507.nc', 'houcsapr2cfrS2.a1.20220604.200524.nc', 'houcsapr2cfrS2.a1.20220604.200540.nc', 'houcsapr2cfrS2.a1.20220604.200554.nc', 'houcsapr2cfrS2.a1.20220604.200607.nc', 'houcsapr2cfrS2.a1.20220604.200637.nc', 'houcsapr2cfrS2.a1.20220604.200654.nc', 'houcsapr2cfrS2.a1.20220604.200711.nc', 'houcsapr2cfrS2.a1.20220604.200724.nc', 'houcsapr2cfrS2.a1.20220604.200740.nc', 'houcsapr2cfrS2.a1.20220604.200809.nc', 'houcsapr2cfrS2.a1.20220604.200824.nc', 'houcsapr2cfrS2.a1.20220604.200839.nc', 'houcsapr2cfrS2.a1.20220604.200853.nc', 'houcsapr2cfrS2.a1.20220604.200909.nc', 'houcsapr2cfrS2.a1.20220604.200938.nc', 'houcsapr2cfrS2.a1.20220604.200954.nc', 'houcsapr2cfrS2.a1.20220604.201009.nc', 'houcsapr2cfrS2.a1.20220604.201024.nc', 'houcsapr2cfrS2.a1.20220604.201037.nc', 'houcsapr2cfrS2.a1.20220604.201107.nc', 'houcsapr2cfrS2.a1.20220604.201125.nc', 'houcsapr2cfrS2.a1.20220604.201141.nc', 'houcsapr2cfrS2.a1.20220604.201154.nc', 'houcsapr2cfrS2.a1.20220604.201208.nc', 'houcsapr2cfrS2.a1.20220604.201237.nc', 'houcsapr2cfrS2.a1.20220604.201255.nc', 'houcsapr2cfrS2.a1.20220604.201310.nc', 'houcsapr2cfrS2.a1.20220604.201323.nc', 'houcsapr2cfrS2.a1.20220604.201338.nc', 'houcsapr2cfrS2.a1.20220604.201407.nc', 'houcsapr2cfrS2.a1.20220604.201423.nc', 'houcsapr2cfrS2.a1.20220604.201439.nc', 'houcsapr2cfrS2.a1.20220604.201454.nc', 'houcsapr2cfrS2.a1.20220604.201509.nc', 'houcsapr2cfrS2.a1.20220604.201538.nc', 'houcsapr2cfrS2.a1.20220604.201555.nc', 'houcsapr2cfrS2.a1.20220604.201608.nc', 'houcsapr2cfrS2.a1.20220604.201624.nc', 'houcsapr2cfrS2.a1.20220604.201637.nc', 'houcsapr2cfrS2.a1.20220604.201707.nc', 'houcsapr2cfrS2.a1.20220604.201723.nc', 'houcsapr2cfrS2.a1.20220604.201738.nc', 'houcsapr2cfrS2.a1.20220604.201754.nc', 'houcsapr2cfrS2.a1.20220604.201808.nc', 'houcsapr2cfrS2.a1.20220604.201837.nc', 'houcsapr2cfrS2.a1.20220604.201855.nc', 'houcsapr2cfrS2.a1.20220604.201909.nc', 'houcsapr2cfrS2.a1.20220604.201924.nc', 'houcsapr2cfrS2.a1.20220604.201937.nc', 'houcsapr2cfrS2.a1.20220604.202007.nc', 'houcsapr2cfrS2.a1.20220604.202025.nc', 'houcsapr2cfrS2.a1.20220604.202038.nc', 'houcsapr2cfrS2.a1.20220604.202054.nc', 'houcsapr2cfrS2.a1.20220604.202106.nc', 'houcsapr2cfrS2.a1.20220604.202136.nc', 'houcsapr2cfrS2.a1.20220604.202150.nc', 'houcsapr2cfrS2.a1.20220604.202205.nc', 'houcsapr2cfrS2.a1.20220604.202219.nc', 'houcsapr2cfrS2.a1.20220604.202233.nc', 'houcsapr2cfrS2.a1.20220604.202303.nc', 'houcsapr2cfrS2.a1.20220604.202319.nc', 'houcsapr2cfrS2.a1.20220604.202335.nc', 'houcsapr2cfrS2.a1.20220604.202349.nc', 'houcsapr2cfrS2.a1.20220604.202403.nc', 'houcsapr2cfrS2.a1.20220604.202433.nc', 'houcsapr2cfrS2.a1.20220604.202452.nc', 'houcsapr2cfrS2.a1.20220604.202511.nc', 'houcsapr2cfrS2.a1.20220604.202526.nc', 'houcsapr2cfrS2.a1.20220604.202537.nc', ...

# %%
testpath = './csapr_test/'
if False:       #...This is just a test with a single filename, can be ignored
    fname = june4_csapr_files[243]
    #nc = Dataset(basepath+fname[:-3]+'_proc.nc','r+')
    #nc = Dataset(testpath+fname[:-3]+'_proc.nc','r+')
    # nc = Dataset(testpath+fname,'r+')
    # nc.renameVariable(u'specific_differential_phase',u'old_kdp')
    # nc.close()
    #radar = pyart.io.read(testpath+fname[:-3]+'_proc.nc')
    radar = pyart.io.read(testpath+fname)

    #zc = deepcopy(radar.fields['reflectivity']['data'])    
    #radar.add_field_like('reflectivity', 'ZC', zc, replace_existing=True)
    # retrieve = DualPolRetrieval(radar, dz='reflectivity',
    #                             dr='differential_reflectivity',dp='differential_phase', 
    #                           rh='cross_correlation_ratio', 
    #                           fhc_T_factor=2, kdp_window=2,ice_flag=False, 
    #                           rain_method='hidro', qc_flag=True, gs=100.0, 
    #                           verbose=True, thresh_sdp=20.0, speckle=3)
    retrieve = DualPolRetrieval(radar, gs=100.0, dz='reflectivity',
                              dr='differential_reflectivity',
                              #dr='RD',
                              dp='differential_phase',
                              rh='copol_correlation_coeff',
                              #fhc_T_factor=2, ice_flag=True,
                              #fhc_flag=False, ice_flag=False,dsd_flag=False,precip_flag=False,liquid_ice_flag=False,
                              fhc_flag=True, ice_flag=False,dsd_flag=True,precip_flag=True,liquid_ice_flag=False,
                              kdp_window=1.8, thresh_sdp=20.0, speckle=3,
                              #kdp_window=5, thresh_sdp=20.0, speckle=3,   #..prev
                              #kdp_window=5, thresh_sdp=20.0, speckle=10,
                              kdp_method='CSU',
                              rain_method='hidro',
                              qc_flag=True, verbose=False)
    pyart.io.write_cfradial(testpath+fname[:-3] + '_proc.nc', radar)

# %% [markdown]
# ## Plot figures, including NEXRAD thing

# %% [markdown]
# ### Do main plots (run this after 4.2)

# %%
#...This is an example to test plotting
fname = june4_csapr_files[393]
radar = pyart.io.read(testpath+fname[:-3]+'_proc.nc')
#..
maxx = 25
maxz = 12
fig = plt.figure(figsize=(6, 15))
ax = fig.add_subplot(311)
display = pyart.graph.RadarDisplay(radar)
display.plot("reflectivity", 0,vmin=-10,vmax=64,cmap=pcm.LangRainbow12)
ax.plot([0,maxx],[melt_0604,melt_0604],'k:',lw=2)
ax.set_xlim(0,maxx)
ax.set_ylim(0,maxz)
#..
ax = fig.add_subplot(312)
display = pyart.graph.RadarDisplay(radar)
#display.plot("differential_reflectivity", 0)
#display.plot("differential_reflectivity",0,vmin=-1,vmax=5,
display.plot("attenuation_corrected_differential_reflectivity",0,vmin=-1,vmax=5,
             cmap=pcm.BuOrR14, mask_tuple=['reflectivity', -5.])
             #cmap=pcm.RefDiff)
             #cmap=pcm.RefDiff)
ax.plot([0,maxx],[melt_0604,melt_0604],'k:',lw=2)
ax.set_xlim(0,maxx)
ax.set_ylim(0,maxz)
#..
ax = fig.add_subplot(313)
display = pyart.graph.RadarDisplay(radar)
#display.plot("KDP_CSU", 0,vmin=-1.5,vmax=4.,cmap=cm.gist_stern)
display.plot("specific_differential_phase", 0,vmin=-1.5,vmax=4.,cmap=cm.gist_stern)
ax.plot([0,maxx],[melt_0604,melt_0604],'k:',lw=2)
ax.set_xlim(0,maxx)
ax.set_ylim(0,maxz)
fig.patch.set_facecolor('white')
fig.tight_layout()
fig.savefig("example_defkdp.png", dpi=200)
#plt.close(fig)
#fig.clf()

# %%
#..This is the main plotting routine
#..
maxx = 25
maxz = 12
#for idx in [236,]:
for idx in csapr_idx1:
    fname = june17_csapr_files[idx]
    fig = plt.figure(figsize=(6, 18))
    gs = gridspec.GridSpec(4,1)
    #..
    radar = pyart.io.read(testpath+fname[-36:-3]+'_proc.nc')
    ax1 = fig.add_subplot(gs[0])
    display = pyart.graph.RadarDisplay(radar)
    display.plot("reflectivity", 0,vmin=-10,vmax=64,cmap=pcm.LangRainbow12,ax=ax1)
    ax1.plot([0,maxx],[melt_0617,melt_0617],'k:',lw=2)
    ax1.set_xlim(0,maxx)
    ax1.set_ylim(0,maxz)
    #..
    ax2 = fig.add_subplot(gs[1])
    display = pyart.graph.RadarDisplay(radar)
    #display.plot("differential_reflectivity", 0)
    #display.plot("differential_reflectivity",0,vmin=-1,vmax=5,
    display.plot("attenuation_corrected_differential_reflectivity",0,vmin=-1,vmax=5,
                 cmap=pcm.BuOrR14, mask_tuple=['reflectivity', -5.],ax=ax2)
                 #cmap=pcm.RefDiff)
                 #cmap=pcm.RefDiff)
    ax2.plot([0,maxx],[melt_0617,melt_0617],'k:',lw=2)
    ax2.set_xlim(0,maxx)
    ax2.set_ylim(0,maxz)
    #..
    ax3 = fig.add_subplot(gs[2])
    display = pyart.graph.RadarDisplay(radar)
    display.plot("KDP_CSU", 0,vmin=-2.0,vmax=5.,cmap=cm.gist_stern,ax=ax3)
    #display.plot("specific_differential_phase", 0,vmin=-1.5,vmax=4.,cmap=cm.gist_stern)
    ax3.plot([0,maxx],[melt_0617,melt_0617],'k:',lw=2)
    ax3.set_xlim(0,maxx)
    ax3.set_ylim(0,maxz)
    #..
    #..
    #...
    # Setting projection and ploting the second tilt
    projection = ccrs.LambertConformal(central_latitude=csapr_lat,
                                       central_longitude=csapr_lon)
    ax4  = fig.add_subplot(gs[3],projection=projection)
    numba = int(fname[-9:-3])
    thing = min(enumerate(khgx_times), key=lambda x: abs(x[1]-numba))
    if (thing[1]>numba):
        nexidx = thing[0]-1
    else:
        nexidx = thing[0]
    radar = pyart.io.read(testpath+fname[-36:-3]+'_proc.nc')
    az = radar.azimuth['data'][0]
    csapr_lat = radar.latitude['data'][0]
    csapr_lon = radar.longitude['data'][0]
    del radar
    radar = read_nexrad_key(keys[nexidx])
    display = pyart.graph.RadarMapDisplay(radar)

    lon_off = .4
    lat_off = .3
    display.plot_ppi_map('reflectivity', 2, ax=ax4, vmin=-4, vmax=64,
                         min_lon=csapr_lon-lon_off, max_lon=csapr_lon+lon_off, 
                         min_lat=csapr_lat-lat_off, max_lat=csapr_lat+lat_off,
                         lon_lines=np.arange(-158, -154, .2), resolution='10m',
                         lat_lines=np.arange(69, 72, .1), projection=projection,
                         fig=fig, lat_0=csapr_lat,
                         lon_0=csapr_lon)
    g = Geod(ellps='sphere')
    lon = csapr_lon
    lat = csapr_lat
    rng = 1000 *25
    lon2, lat2, _ = g.fwd(lon, lat, az, rng)
    plt.plot([csapr_lon, lon2], [csapr_lat, lat2], transform=ccrs.Geodetic(),c='r',lw=2)
    display.plot_point(csapr_lon, csapr_lat,c='r')
    #...
    #...
    fig.patch.set_facecolor('white')
    fig.tight_layout()
    fig.savefig('./csapr_figs/rhi_'+fname[-36:-3]+'.png', dpi=200)
    plt.close(fig)
    fig.clf()

# %%
print(radar.fields)
# Out:
# {'attenuation_corrected_differential_reflectivity': {'_FillValue': -32767.0, 'long_name': 'Rainfall attenuation-corrected differential reflectivity', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[  7.9947205 ,  -1.9256239 ,   5.012208  , ...,  10.270708  ,
#            1.2583165 ,  30.        ],
#         [  5.3105354 ,   5.161753  ,  20.91131   , ...,  30.        ,
#          -20.        ,  -0.13336992],
#         [  0.54110956,   7.1684065 ,  23.850332  , ..., -20.        ,
#           -0.13336992, -20.        ],
#         ...,
#         [  7.5926266 ,   5.104529  ,   4.34841   , ...,  -2.1674905 ,
#            1.1194532 ,   0.05050993],
#         [  8.233535  ,   5.0877433 ,   4.461332  , ..., -20.        ,
#           -0.13336992,   1.6489654 ],
#         [ 13.138772  ,   3.2893853 ,   5.3433437 , ...,   0.89971304,
#           -0.13336992,  -0.13336992]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'attenuation_corrected_differential_reflectivity_lag_1': {'_FillValue': -32767.0, 'long_name': 'Differential reflectivity estimated at lag 1 corrected for rainfall attenuation.', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 7.4219737e+00, -1.1981931e+00,  7.3689952e+00, ...,
#           7.3682981e+00,  2.7405286e-01,  6.2835932e-02],
#         [ 4.8580914e+00,  6.2696905e+00,  2.2189045e+01, ...,
#           7.0190582e+00, -1.6708174e+00, -6.6771030e-01],
#         [-1.5237808e-02,  8.9911146e+00,  2.5356606e+01, ...,
#           1.2813424e+00,  6.9354076e+00, -6.0915518e-01],
#         ...,
#         [-1.7412229e+00,  5.6973829e+00,  5.3983326e+00, ...,
#          -5.1032691e+00,  6.9235573e+00,  7.6366763e+00],
#         [ 1.0806327e+01,  4.6113224e+00,  5.5028958e+00, ...,
#          -1.1919193e+00,  4.7361012e+00,  1.5218371e+00],
#         [ 1.7585489e+01, -7.5681658e+00,  6.3679800e+00, ...,
#          -5.9154272e-02,  1.0715195e+00,  5.8388910e+00]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'attenuation_corrected_reflectivity_h': {'_FillValue': -32767.0, 'long_name': 'Rainfall attenuation-corrected reflectivity, horizontal channel', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'equivalent_reflectivity_factor', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[16.42726707458496, 27.604021072387695, --, ...,
#          -6.458559036254883, --, -3.880202054977417],
#         [14.141201972961426, 28.207962036132812, --, ...,
#          1.148756980895996, --, --],
#         [14.694812774658203, 20.881322860717773, --, ..., --, --, --],
#         ...,
#         [9.826518058776855, 15.658793449401855, 28.891263961791992, ...,
#          -12.470855712890625, --, --],
#         [3.4948301315307617, 13.643726348876953, 26.291614532470703, ...,
#          --, --, --],
#         [11.787385940551758, 7.9275922775268555, 20.76324462890625, ...,
#          --, --, --]],
#   mask=[[False, False,  True, ..., False,  True, False],
#         [False, False,  True, ..., False,  True,  True],
#         [False, False,  True, ...,  True,  True,  True],
#         ...,
#         [False, False, False, ..., False,  True,  True],
#         [False, False, False, ...,  True,  True,  True],
#         [False, False, False, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'censor_mask': {'long_name': 'Censor Mask', 'units': '1', 'flag_masks': array([   1,    2,    4,    8,   16,   32,   64,  128,  256,  512, 1024,
#        2048], dtype=int32), 'flag_meanings': 'horizontal_snr_below_noise_threshold vertical_snr_below_noise_threshold horizontal_ccor_below_ccor_threshold vertical_ccor_below_ccor_threshold horizontal_sqi_below_sqi1_threshold vertical_sqi_below_sqi1_threshold horizontal_sqi_below_sqi2_threshold vertical_sqi_below_sqi2_threshold horizontal_sigpow_below_sigpow_threshold vertical_sigpow_below_sigpow_threshold urhohv_below_rhohv_threshold censored_by_clutter_micro_suppression', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_quality_mask', 'data': masked_array(
#   data=[[120,   0, 120, ..., 120, 120, 120],
#         [120,   0,   0, ..., 120, 120, 120],
#         [120,   0,   0, ..., 120, 120, 120],
#         ...,
#         [ 48,   0,   0, ..., 120, 120, 120],
#         [ 48,   0,   0, ..., 120, 120, 120],
#         [120,  16,   0, ..., 120, 120, 120]],
#   mask=False,
#   fill_value=999999,
#   dtype=int32)}, 'classification_mask': {'long_name': 'Classification Mask', 'units': '1', 'flag_masks': array([ 1,  2,  4,  8, 16], dtype=int32), 'flag_meanings': 'second_trip third_trip interference clutter sunspoke', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_quality_mask', 'data': masked_array(
#   data=[[ 8,  8,  8, ...,  8,  8,  8],
#         [ 8,  8,  8, ...,  8,  8,  8],
#         [ 8,  8,  8, ...,  8,  8,  8],
#         ...,
#         [ 8,  8,  8, ...,  8,  8,  8],
#         [ 8,  8,  8, ...,  8,  8,  8],
#         [12,  8,  8, ...,  8,  8,  8]],
#   mask=False,
#   fill_value=999999,
#   dtype=int32)}, 'copol_correlation_coeff': {'_FillValue': -32767.0, 'long_name': 'Copolar correlation coefficient (also known as rhohv)', 'units': '1', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_correlation_coefficient_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[0.77641165, 0.90934736, 0.701928  , ..., 0.09605241, 0.05771995,
#          0.08711377],
#         [0.782025  , 0.8492937 , 0.9505475 , ..., 0.17283937, 0.11367038,
#          0.11100098],
#         [0.5983099 , 0.49237314, 0.8781231 , ..., 0.19483516, 0.16237533,
#          0.07082283],
#         ...,
#         [0.2189512 , 0.8261844 , 0.9990084 , ..., 0.27095094, 0.02463475,
#          0.18701002],
#         [0.12369204, 0.6376338 , 0.9973153 , ..., 0.17656127, 0.08993569,
#          0.1598585 ],
#         [0.18225086, 0.45544404, 0.9883156 , ..., 0.11005527, 0.08432233,
#          0.02492455]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'differential_phase': {'_FillValue': -32767.0, 'long_name': 'Differential propagation phase shift', 'units': 'degree', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_phase_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ -19.6472  ,  113.79336 , -178.72552 , ...,  -68.802284,
#           107.04744 , -125.15923 ],
#         [  -4.25465 ,  111.40921 , -173.87485 , ...,   50.67401 ,
#           -14.038424, -128.46077 ],
#         [  60.974167,   17.241085, -170.50737 , ...,  -96.642914,
#          -118.54516 ,   99.906   ],
#         ...,
#         [ 112.64523 ,  124.934006,  132.75662 , ...,  -65.31946 ,
#            96.41768 ,   14.137305],
#         [ -69.34613 ,  135.75603 ,  126.14805 , ...,   24.942854,
#          -144.75974 ,  137.14037 ],
#         [  78.24546 ,   99.906   ,  106.67389 , ...,   79.47599 ,
#           -63.2814  ,  -27.101765]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'differential_reflectivity': {'_FillValue': -32767.0, 'long_name': 'Differential reflectivity', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[  7.9948726 ,  -3.4053593 ,   5.012513  , ...,  10.270402  ,
#           -0.13367516,  20.        ],
#         [  5.310383  ,   3.7136056 ,  20.        , ...,  20.        ,
#          -20.        ,  -0.13367516],
#         [ -0.2508698 ,   6.9443936 ,  20.        , ..., -20.        ,
#           -0.13367516, -20.        ],
#         ...,
#         [  6.127693  ,   3.480437  ,   2.62162   , ...,  -2.1674907 ,
#           -0.13367516,  -0.13367516],
#         [  8.233535  ,   3.3229568 ,   2.821217  , ..., -20.        ,
#           -0.13367516,  -0.13367516],
#         [ 12.122322  ,   1.9898676 ,   3.9571507 , ...,  -0.13367516,
#           -0.13367516,  -0.13367516]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'differential_reflectivity_lag_1': {'_FillValue': -32767.0, 'long_name': 'Differential reflectivity estimated at lag 1', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 7.421835  , -2.677158  ,  7.369232  , ...,  7.3678484 ,
#          -1.1177702 ,  0.06301808],
#         [ 4.858154  ,  4.8207784 , 22.18861   , ...,  6.360094  ,
#          -1.670789  , -0.66788006],
#         [-0.8083842 ,  8.767352  , 25.35722   , ...,  1.2818741 ,
#           6.9352617 , -1.9081924 ],
#         ...,
#         [-3.2045677 ,  4.073269  ,  3.6725206 , ..., -5.1031036 ,
#           5.6707244 ,  7.452981  ],
#         [10.806393  ,  2.846107  ,  3.8628588 , ..., -1.5164421 ,
#           4.7363377 , -0.26159477],
#         [16.568445  , -8.866953  ,  4.9813547 , ..., -1.0921609 ,
#           1.071464  ,  5.838914  ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'mean_doppler_velocity': {'_FillValue': -32767.0, 'long_name': 'Radial mean Doppler velocity, positive for motion away from the instrument', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radial_velocity_of_scatterers_away_from_instrument', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[-1.07711904e-01,  1.22308373e-01, -3.72461714e-02, ...,
#           1.30547829e+01,  1.36904850e+01, -3.79306960e+00],
#         [ 6.03991980e-03,  1.60057873e-01, -3.47295403e-02, ...,
#          -1.21201057e+01, -9.88785172e+00, -9.44593143e+00],
#         [ 6.59357905e-02, -5.53659312e-02, -4.58027236e-02, ...,
#           6.92476797e+00,  1.44515152e+01, -1.76214659e+00],
#         ...,
#         [ 9.88785172e+00,  4.43934113e-01,  5.48626035e-02, ...,
#           1.71181393e+00,  5.78120995e+00, -9.25416374e+00],
#         [-2.41999459e+00, -1.63832819e+00,  4.37894203e-02, ...,
#           2.10138869e+00, -1.56720819e+01, -1.62901669e+01],
#         [ 1.39169824e+00,  1.36326027e+01,  7.29823634e-02, ...,
#           4.79368305e+00, -1.19555178e+01, -1.38550730e+01]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'mean_doppler_velocity_v': {'_FillValue': -32767.0, 'long_name': 'Doppler velocity, vertical channel', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radial_velocity_of_scatterers_away_from_instrument', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 2.91920546e-02, -4.52980166e-03, -1.19284771e-01, ...,
#           6.92556334e+00,  2.95846367e+00, -1.14603984e+00],
#         [ 1.10728480e-02,  2.51655638e-01,  1.56026501e-02, ...,
#           1.13823843e+01,  4.46437120e-01, -1.34998150e+01],
#         [ 4.98278178e-02,  9.35655653e-01, -1.52503312e-01, ...,
#           3.64800024e+00,  3.30927157e+00,  1.47017221e+01],
#         ...,
#         [-2.66855645e+00,  1.17271528e-01,  6.64370880e-02, ...,
#          -5.17051697e+00,  1.11302261e+01,  1.37655640e+00],
#         [ 9.33894062e+00, -9.04450357e-01,  7.19735101e-02, ...,
#          -1.97197366e+00,  7.63321877e+00,  6.42325878e+00],
#         [ 8.94686127e+00, -2.65245050e-01,  1.24317884e-01, ...,
#           5.70956326e+00, -1.41279478e+01, -9.92781544e+00]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'normalized_coherent_power': {'_FillValue': -32767.0, 'long_name': 'Normalized coherent power, also known as SQI.', 'units': '1', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_normalized_coherent_power', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[0.66270024, 0.9091381 , 0.99786425, ..., 0.05473688, 0.09749815,
#          0.05292147],
#         [0.67841345, 0.9000305 , 0.9979253 , ..., 0.18918386, 0.14019838,
#          0.11167052],
#         [0.54491234, 0.8916552 , 0.99896264, ..., 0.1160031 , 0.25136542,
#          0.08921438],
#         ...,
#         [0.01704049, 0.736476  , 0.99438596, ..., 0.07334864, 0.20057976,
#          0.19491994],
#         [0.18099165, 0.48834482, 0.98308164, ..., 0.16393596, 0.2995271 ,
#          0.13531661],
#         [0.24010682, 0.035698  , 0.9503585 , ..., 0.16660568, 0.10051873,
#          0.12968731]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'normalized_coherent_power_v': {'_FillValue': -32767.0, 'long_name': 'Normalized coherent power, also known as SQI, Vertical Channel', 'units': '1', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_normalized_coherent_power', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[0.9653431 , 0.981558  , 0.74043965, ..., 0.01337782, 0.17099634,
#          0.07457647],
#         [0.96119404, 0.89037025, 0.949296  , ..., 0.06759018, 0.19311449,
#          0.16974553],
#         [0.7908995 , 0.74809706, 0.9014293 , ..., 0.09515396, 0.07018334,
#          0.13380733],
#         ...,
#         [0.18650955, 0.820248  , 0.9967509 , ..., 0.2903886 , 0.06472245,
#          0.03124014],
#         [0.1277363 , 0.6957152 , 0.9872782 , ..., 0.24375746, 0.14353934,
#          0.17432171],
#         [0.11010277, 0.555059  , 0.9584179 , ..., 0.1641626 , 0.12088728,
#          0.03496209]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'reflectivity': {'_FillValue': -32767.0, 'long_name': 'Equivalent reflectivity factor', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'equivalent_reflectivity_factor', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'reflectivity_v': {'_FillValue': -32767.0, 'long_name': 'Equivalent reflectivity factor, vertical channel', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'equivalent_reflectivity_factor', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[9.025615692138672, 23.297189712524414, 33.68834686279297, ...,
#          -16.13416862487793, -80.0, -80.0],
#         [9.424535751342773, 16.954978942871094, 18.087745666503906, ...,
#          -80.0, -10.451138496398926, -80.0],
#         [11.090620040893555, 13.270822525024414, 14.951837539672852, ...,
#          -13.670242309570312, -80.0, -4.0662617683410645],
#         ...,
#         [-3.931865692138672, 3.6519079208374023, 17.168306350708008, ...,
#          -9.708760261535645, -80.0, -80.0],
#         [-4.145192623138428, 1.0045204162597656, 14.857975006103516, ...,
#          -42.93444061279297, -80.0, -80.0],
#         [-5.452887058258057, -0.7596940994262695, 9.612264633178711, ...,
#          -80.0, -80.0, -80.0]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'signal_to_noise_ratio_copolar_h': {'_FillValue': -32767.0, 'long_name': 'Signal-to-noise ratio, horizontal channel', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_signal_to_noise_ratio_copolar_h', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 80.765976 ,  74.09652  ,  88.46573  , ..., -10.699484 ,
#          -31.999998 ,  -8.143652 ],
#         [ 78.48147  ,  74.87067  ,  88.763626 , ...,  -6.7926846,
#          -31.999998 , -31.999998 ],
#         [ 74.58605  ,  74.41908  ,  88.56629  , ..., -31.999998 ,
#          -31.999998 , -31.999998 ],
#         ...,
#         [ 65.943275 ,  61.336323 ,  69.55408  , ..., -16.712431 ,
#          -31.999998 , -31.999998 ],
#         [ 67.83691  ,  58.531925 ,  67.44224  , ..., -31.999998 ,
#          -31.999998 , -31.999998 ],
#         [ 70.41361  ,  55.433426 ,  63.334312 , ..., -31.999998 ,
#          -31.999998 , -31.999998 ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'signal_to_noise_ratio_copolar_v': {'_FillValue': -32767.0, 'long_name': 'Signal-to-noise ratio, vertical channel', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_signal_to_noise_ratio_copolar_v', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 72.63805 ,  77.36559 ,  83.320854, ..., -21.105257, -32.      ,
#          -32.      ],
#         [ 73.0371  ,  71.022736,  67.71956 , ..., -32.      , -15.434492,
#          -32.      ],
#         [ 74.703964,  67.33769 ,  64.582504, ..., -18.642199, -32.      ,
#           -9.053446],
#         ...,
#         [ 59.681206,  57.720303,  66.799255, ..., -14.678389, -32.      ,
#          -32.      ],
#         [ 59.467354,  55.073944,  64.48704 , ..., -32.      , -32.      ,
#          -32.      ],
#         [ 58.157543,  53.309708,  59.242054, ..., -32.      , -32.      ,
#          -32.      ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'specific_differential_phase': {'_FillValue': -32767.0, 'long_name': 'Specific differential phase (KDP)', 'units': 'degree/km', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_specific_differential_phase_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ -5.2270646,  -5.2838306,  -5.3131294, ...,   0.       ,
#            0.       ,   0.       ],
#         [ -1.9767442,  -2.203351 ,  -2.4020326, ...,   0.       ,
#            0.       ,   0.       ],
#         [ 15.       ,  15.       ,  15.       , ...,   0.       ,
#            0.       ,   0.       ],
#         ...,
#         [  2.1713057,   2.1323934,   2.0916498, ...,   0.       ,
#            0.       ,   0.       ],
#         [-15.       , -15.       , -15.       , ...,   0.       ,
#            0.       ,   0.       ],
#         [  2.812214 ,   2.8552463,   2.9097235, ...,   0.       ,
#            0.       ,   0.       ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'spectral_width': {'_FillValue': -32767.0, 'long_name': 'Spectral width', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_doppler_spectrum_width', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 4.7619495,  2.2914329, 16.492    , ...,  4.4503055,  7.9458027,
#           7.12607  ],
#         [ 4.6243634,  2.4093995, 16.492    , ...,  2.2172318,  6.2288666,
#           5.601553 ],
#         [ 5.784666 ,  2.5142875, 16.492    , ...,  1.9264641,  4.1872063,
#           4.947075 ],
#         ...,
#         [14.982073 ,  4.106214 ,  0.556386 , ...,  8.3228445,  4.6107807,
#           8.422954 ],
#         [ 9.706002 ,  6.2852087,  0.9693966, ...,  2.2881627, 14.1215925,
#           5.1840153],
#         [ 8.867405 , 13.553137 ,  1.6751866, ...,  9.45548  ,  5.9164677,
#           8.558527 ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'spectral_width_v': {'_FillValue': -32767.0, 'long_name': 'Spectral Width, Vertical Channel', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_doppler_spectrum_width', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 1.3943133 ,  1.0127211 ,  4.0699897 , ...,  5.522155  ,
#           3.921327  , 14.714336  ],
#         [ 1.4770718 ,  2.5297842 ,  1.6933994 , ...,  6.3474717 ,
#          10.3336935 ,  4.8641148 ],
#         [ 3.595829  ,  3.9998088 ,  2.3916864 , ..., 10.377462  ,
#           9.12276   ,  3.2441702 ],
#         ...,
#         [ 9.620565  ,  3.3045406 ,  0.4225979 , ..., 10.953751  ,
#           4.486044  , 10.47808   ],
#         [10.649633  ,  4.471706  ,  0.83965826, ..., 16.491749  ,
#           2.5411038 ,  2.5390916 ],
#         [11.027452  ,  5.6962233 ,  1.5301476 , ...,  2.8754063 ,
#           8.714503  , 10.357339  ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_copol_correlation_coeff': {'_FillValue': -32767.0, 'long_name': 'Uncorrected copolar correlation coefficient', 'units': '1', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_correlation_coefficient_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[0.77641165, 0.90934736, 0.701928  , ..., 0.09605241, 0.05771995,
#          0.08711377],
#         [0.782025  , 0.8492937 , 0.9505475 , ..., 0.17283937, 0.11367038,
#          0.11100098],
#         [0.5983099 , 0.49237314, 0.8781231 , ..., 0.19483516, 0.16237533,
#          0.07082283],
#         ...,
#         [0.2189512 , 0.8261844 , 0.9990084 , ..., 0.27095094, 0.02463475,
#          0.18701002],
#         [0.12369204, 0.6376338 , 0.9973153 , ..., 0.17656127, 0.08993569,
#          0.1598585 ],
#         [0.18225086, 0.45544404, 0.9883156 , ..., 0.11005527, 0.08432233,
#          0.02492455]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_differential_phase': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Differential Phase', 'units': 'degree', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_phase_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ -19.6472  ,  113.79336 , -178.72552 , ...,  -68.802284,
#           107.04744 , -125.15923 ],
#         [  -4.25465 ,  111.40921 , -173.87485 , ...,   50.67401 ,
#           -14.038424, -128.46077 ],
#         [  60.974167,   17.241085, -170.50737 , ...,  -96.642914,
#          -118.54516 ,   99.906   ],
#         ...,
#         [ 112.64523 ,  124.934006,  132.75662 , ...,  -65.31946 ,
#            96.41768 ,   14.137305],
#         [ -69.34613 ,  135.75603 ,  126.14805 , ...,   24.942854,
#          -144.75974 ,  137.14037 ],
#         [  78.24546 ,   99.906   ,  106.67389 , ...,   79.47599 ,
#           -63.2814  ,  -27.101765]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_differential_reflectivity': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Differential Reflectivity, Vertical Channel', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[  7.9948726 ,  -3.405054  ,   5.0128183 , ...,  10.270097  ,
#           -0.13367516,  30.        ],
#         [  5.310383  ,   3.7136056 ,  20.911005  , ...,  30.        ,
#          -30.        ,  -0.13367516],
#         [ -0.2508698 ,   6.9437833 ,  23.850027  , ..., -30.        ,
#           -0.13367516, -30.        ],
#         ...,
#         [  6.1279984 ,   3.4801319 ,   2.6213148 , ...,  -2.1671855 ,
#           -0.13367516,  -0.13367516],
#         [  8.232924  ,   3.3226516 ,   2.820912  , ..., -30.        ,
#           -0.13367516,  -0.13367516],
#         [ 12.122322  ,   1.9895624 ,   3.9571507 , ...,  -0.13367516,
#           -0.13367516,  -0.13367516]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_differential_reflectivity_lag_1': {'_FillValue': -32767.0, 'long_name': 'Uncorrected differential reflectivity estimated at lag 1', 'units': 'dB', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_differential_reflectivity_hv', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 7.421835  , -2.677158  ,  7.369232  , ...,  7.3678484 ,
#          -1.1177702 ,  0.06301808],
#         [ 4.858154  ,  4.8207784 , 22.18861   , ...,  6.360094  ,
#          -1.670789  , -0.66788006],
#         [-0.8083842 ,  8.767352  , 25.35722   , ...,  1.2818741 ,
#           6.9352617 , -1.9081924 ],
#         ...,
#         [-3.2045677 ,  4.073269  ,  3.6725206 , ..., -5.1031036 ,
#           5.6707244 ,  7.452981  ],
#         [10.806393  ,  2.846107  ,  3.8628588 , ..., -1.5164421 ,
#           4.7363377 , -0.26159477],
#         [16.568445  , -8.866953  ,  4.9813547 , ..., -1.0921609 ,
#           1.071464  ,  5.838914  ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_mean_doppler_velocity_h': {'_FillValue': -32767.0, 'long_name': 'Radial mean Doppler velocity from horizontal channel, positive for motion away from the instrument, uncorrected', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radial_velocity_of_scatterers_away_from_instrument', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[-1.07711904e-01,  1.22308373e-01, -3.72461714e-02, ...,
#           1.30547829e+01,  1.36904850e+01, -3.79306960e+00],
#         [ 6.03991980e-03,  1.60057873e-01, -3.47295403e-02, ...,
#          -1.21201057e+01, -9.88785172e+00, -9.44593143e+00],
#         [ 6.59357905e-02, -5.53659312e-02, -4.58027236e-02, ...,
#           6.92476797e+00,  1.44515152e+01, -1.76214659e+00],
#         ...,
#         [ 9.88785172e+00,  4.43934113e-01,  5.48626035e-02, ...,
#           1.71181393e+00,  5.78120995e+00, -9.25416374e+00],
#         [-2.41999459e+00, -1.63832819e+00,  4.37894203e-02, ...,
#           2.10138869e+00, -1.56720819e+01, -1.62901669e+01],
#         [ 1.39169824e+00,  1.36326027e+01,  7.29823634e-02, ...,
#           4.79368305e+00, -1.19555178e+01, -1.38550730e+01]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_mean_doppler_velocity_v': {'_FillValue': -32767.0, 'long_name': 'Radial mean Doppler velocity from vertical channel, positive for motion away from the instrument, uncorrected', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radial_velocity_of_scatterers_away_from_instrument', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 2.91920546e-02, -4.52980166e-03, -1.19284771e-01, ...,
#           6.92556334e+00,  2.95846367e+00, -1.14603984e+00],
#         [ 1.10728480e-02,  2.51655638e-01,  1.56026501e-02, ...,
#           1.13823843e+01,  4.46437120e-01, -1.34998150e+01],
#         [ 4.98278178e-02,  9.35655653e-01, -1.52503312e-01, ...,
#           3.64800024e+00,  3.30927157e+00,  1.47017221e+01],
#         ...,
#         [-2.66855645e+00,  1.17271528e-01,  6.64370880e-02, ...,
#          -5.17051697e+00,  1.11302261e+01,  1.37655640e+00],
#         [ 9.33894062e+00, -9.04450357e-01,  7.19735101e-02, ...,
#          -1.97197366e+00,  7.63321877e+00,  6.42325878e+00],
#         [ 8.94686127e+00, -2.65245050e-01,  1.24317884e-01, ...,
#           5.70956326e+00, -1.41279478e+01, -9.92781544e+00]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_reflectivity_h': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Reflectivity, Horizontal Channel', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'equivalent_reflectivity_factor', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[16.42726707458496, 19.297916412353516, 38.10715103149414, ...,
#          -6.458559036254883, --, -3.880202054977417],
#         [14.141201972961426, 20.074132919311523, 38.407188415527344, ...,
#          -2.5503733158111572, --, --],
#         [10.244629859924316, 19.621179580688477, 38.20780944824219, ...,
#          --, --, --],
#         ...,
#         [1.601711630821228, 6.539691925048828, 19.199195861816406, ...,
#          -12.470855712890625, --, --],
#         [3.4948301315307617, 3.7348573207855225, 17.083471298217773, ...,
#          --, --, --],
#         [6.073187828063965, 0.6357954144477844, 12.975908279418945, ...,
#          --, --, --]],
#   mask=[[False, False, False, ..., False,  True, False],
#         [False, False, False, ..., False,  True,  True],
#         [False, False, False, ...,  True,  True,  True],
#         ...,
#         [False, False, False, ..., False,  True,  True],
#         [False, False, False, ...,  True,  True,  True],
#         [False, False, False, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'uncorrected_reflectivity_v': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Reflectivity, Vertical Channel', 'units': 'dBZ', 'coordinates': 'elevation azimuth range', 'standard_name': 'equivalent_reflectivity_factor', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[9.023921966552734, 23.298072814941406, 33.68947982788086, ...,
#          -16.134798049926758, --, --],
#         [9.425077438354492, 16.955028533935547, 18.08856964111328, ...,
#          --, -10.452371597290039, --],
#         [11.092266082763672, 13.269180297851562, 14.951089859008789, ...,
#          -13.670818328857422, --, -4.0651631355285645],
#         ...,
#         [-3.9289910793304443, 3.6543240547180176, 17.168487548828125,
#          ..., -9.70710563659668, --, --],
#         [-4.144289970397949, 1.004488229751587, 14.8572416305542, ...,
#          -42.93310546875, --, --],
#         [-5.450806617736816, -0.7565485835075378, 9.612774848937988, ...,
#          --, --, --]],
#   mask=[[False, False, False, ..., False,  True,  True],
#         [False, False, False, ...,  True, False,  True],
#         [False, False, False, ..., False,  True, False],
#         ...,
#         [False, False, False, ..., False,  True,  True],
#         [False, False, False, ..., False,  True,  True],
#         [False, False, False, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'uncorrected_spectral_width_h': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Spectral Width, Horizontal Channel', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_doppler_spectrum_width', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 4.7619495,  2.2914329, 16.492    , ...,  4.4503055,  7.9458027,
#           7.12607  ],
#         [ 4.6243634,  2.4093995, 16.492    , ...,  2.2172318,  6.2288666,
#           5.601553 ],
#         [ 5.784666 ,  2.5142875, 16.492    , ...,  1.9264641,  4.1872063,
#           4.947075 ],
#         ...,
#         [14.982073 ,  4.106214 ,  0.556386 , ...,  8.3228445,  4.6107807,
#           8.422954 ],
#         [ 9.706002 ,  6.2852087,  0.9693966, ...,  2.2881627, 14.1215925,
#           5.1840153],
#         [ 8.867405 , 13.553137 ,  1.6751866, ...,  9.45548  ,  5.9164677,
#           8.558527 ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'uncorrected_spectral_width_v': {'_FillValue': -32767.0, 'long_name': 'Uncorrected Spectral Width, Vertical Channel', 'units': 'm/s', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_doppler_spectrum_width', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[ 1.3943133 ,  1.0127211 ,  4.0699897 , ...,  5.522155  ,
#           3.921327  , 14.714336  ],
#         [ 1.4770718 ,  2.5297842 ,  1.6933994 , ...,  6.3474717 ,
#          10.3336935 ,  4.8641148 ],
#         [ 3.595829  ,  3.9998088 ,  2.3916864 , ..., 10.377462  ,
#           9.12276   ,  3.2441702 ],
#         ...,
#         [ 9.620565  ,  3.3045406 ,  0.4225979 , ..., 10.953751  ,
#           4.486044  , 10.47808   ],
#         [10.649633  ,  4.471706  ,  0.83965826, ..., 16.491749  ,
#           2.5411038 ,  2.5390916 ],
#         [11.027452  ,  5.6962233 ,  1.5301476 , ...,  2.8754063 ,
#           8.714503  , 10.357339  ]],
#   mask=False,
#   fill_value=1e+20,
#   dtype=float32)}, 'unthresholded_power_copolar_h': {'_FillValue': -32767.0, 'long_name': 'Received copolar power, h channel, without thresholding.', 'units': 'dBm', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_received_signal_power_copolar_h', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[92.1434326171875, 85.47286987304688, --, ...,
#          0.6775398254394531, 6.109123229980469, 3.234241485595703],
#         [89.85831451416016, 86.2474365234375, --, ..., 5.358661651611328,
#          4.818717956542969, 3.549205780029297],
#         [85.96461486816406, 85.79588317871094, --, ...,
#          1.8667030334472656, 6.031986236572266, 2.244342803955078],
#         ...,
#         [77.3206787109375, 72.715087890625, 80.93156433105469, ...,
#          5.580425262451172, 5.520969390869141, 7.547367095947266],
#         [79.21369934082031, 69.90930938720703, 78.81999206542969, ...,
#          3.216564178466797, 21.820531845092773, 3.9445228576660156],
#         [81.79129028320312, 66.8110580444336, 74.71095275878906, ...,
#          7.982856750488281, 3.4045791625976562, 6.5462188720703125]],
#   mask=[[False, False,  True, ..., False, False, False],
#         [False, False,  True, ..., False, False, False],
#         [False, False,  True, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'unthresholded_power_copolar_v': {'_FillValue': -32767.0, 'long_name': 'Received copolar power, v channel, without thresholding', 'units': 'dBm', 'coordinates': 'elevation azimuth range', 'standard_name': 'radar_received_signal_power_copolar_v', 'unpacking_details': 'Can be unpacked as follows: multiply packed values by scale_factor field attribute, then add the add_offset field attribute.', 'data': masked_array(
#   data=[[84.04740905761719, 88.77720642089844, 94.72994232177734, ...,
#          -4.888935089111328, 4.424873352050781, 17.192081451416016],
#         [84.44749450683594, 82.43409729003906, 79.12971496582031, ...,
#          2.745147705078125, 12.807302474975586, 4.567417144775391],
#         [86.11588287353516, 78.74906921386719, 75.9937973022461, ...,
#          9.741033554077148, 5.233150482177734, 4.015068054199219],
#         ...,
#         [71.09392547607422, 69.13235473632812, 78.20967102050781, ...,
#          15.641939163208008, 0.7187881469726562, 4.1154937744140625],
#         [70.87849426269531, 66.48399353027344, 75.89823150634766, ...,
#          47.05458068847656, 2.840717315673828, 3.5566673278808594],
#         [69.5697021484375, 64.72166442871094, 70.65171813964844, ...,
#          3.6408958435058594, 6.517646789550781, 4.350364685058594]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'FDP_CSU': {'_FillValue': -32767.0, 'long_name': 'Filtered Differential Phase', 'units': 'deg', 'standard_name': 'Filtered Differential Phase', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'SDP_CSU': {'_FillValue': -32767.0, 'long_name': 'Standard Deviation of Differential Phase', 'units': 'deg', 'standard_name': 'Std Dev Differential Phase', 'data': masked_array(
#   data=[[100.0, 100.0, --, ..., 100.0, 100.0, 100.0],
#         [100.0, 100.0, --, ..., 100.0, 100.0, 100.0],
#         [100.0, 100.0, --, ..., 100.0, 100.0, 100.0],
#         ...,
#         [100.0, 100.0, 100.0, ..., 100.0, 100.0, 100.0],
#         [100.0, 100.0, 100.0, ..., 100.0, 100.0, 100.0],
#         [100.0, 100.0, 100.0, ..., 100.0, 100.0, 100.0]],
#   mask=[[False, False,  True, ..., False, False, False],
#         [False, False,  True, ..., False, False, False],
#         [False, False,  True, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'KDP_CSU': {'_FillValue': -32767.0, 'long_name': 'Specific Differential Phase', 'units': 'deg km-1', 'standard_name': 'KDP', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'FH': {'_FillValue': -32767.0, 'long_name': 'Hydrometeor ID', 'units': 'unitless', 'standard_name': 'Hydrometeor ID', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'rain': {'_FillValue': -32767.0, 'long_name': 'Rainfall Rate', 'units': 'mm h-1', 'standard_name': 'Rainfall Rate', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'method': {'_FillValue': -32767, 'long_name': 'Rainfall Method', 'units': '', 'standard_name': 'Rainfall Method', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767,
#   dtype=int16)}, 'D0': {'_FillValue': -32767.0, 'long_name': 'Median Volume Diameter', 'units': 'mm', 'standard_name': 'Median Volume Diameter', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'NW': {'_FillValue': -32767.0, 'long_name': 'Normalized Intercept Parameter', 'units': 'mm-1 m-3', 'standard_name': 'Normalized Intercept Parameter', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}, 'MU': {'_FillValue': -32767.0, 'long_name': 'Mu', 'units': ' ', 'standard_name': 'Mu', 'data': masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32767.0,
#   dtype=float32)}}

# %%
print(radar.azimuth['data'][0])
# Out:
# 29.152222

# %% [markdown]
# ### Download NEXRAD (run this before 4.1)

# %%
#del keys
#keys = get_nexrad_keys('KHGX',start='20220604_210000',end='20220604_235000')
keys = get_nexrad_keys('KHGX',start='20220617_190000',end='20220617_230000')
for key in keys:
    fname = os.path.split(str(key))[1][:-1]
    radar = read_nexrad_key(key)
    fnams = fname[0:4]+'_'+fname[-3:]+'_'+fname[4:8]+'_'+fname[8:12]+'_'+fname[13:19]+'.nc'
    pyart.io.write_cfradial(fnams,radar)
# Out:
# Found 65 keys.

# %%
print(int(fname[13:19]))
# Out:
# 225855

# %%
#..Get times for each nexrad
khgx_times = []
for key in keys:
    fname = os.path.split(str(key))[1][:-1]
    khgx_times = np.r_[khgx_times,int(fname[13:19])]

# %%
print(testpath)
print(fname)
# Out:
# ./csapr_test_0617/
# /home/marcus/Research/Jupyter_NB/ASR_TRACER/houcsapr2cfrS2.a1/houcsapr2cfrS2.a1.20220617.201928.nc

# %%
#..Test out plot of nexrad with line showing closest (after) CSAPR RHI direction
idx = 240
fname = june17_csapr_files[idx]
numba = int(fname[-9:-3])
print(numba)
thing = min(enumerate(khgx_times), key=lambda x: abs(x[1]-numba))
print(thing)
if (thing[1]>numba):
    nexidx = thing[0]-1
else:
    nexidx = thing[0]
radar = pyart.io.read(testpath+fname[-36:-3]+'_proc.nc')
az = radar.azimuth['data'][0]
csapr_lat = radar.latitude['data'][0]
csapr_lon = radar.longitude['data'][0]
del radar
radar = read_nexrad_key(keys[nexidx])
display = pyart.graph.RadarMapDisplay(radar)

# Setting projection and ploting the second tilt
projection = ccrs.LambertConformal(central_latitude=csapr_lat,
                                   central_longitude=csapr_lon)
fig = plt.figure(figsize=(6,6))
lon_off = .4
lat_off = .3
display.plot_ppi_map('reflectivity', 2, vmin=-4, vmax=64,
                     min_lon=csapr_lon-lon_off, max_lon=csapr_lon+lon_off, 
                     min_lat=csapr_lat-lat_off, max_lat=csapr_lat+lat_off,
                     lon_lines=np.arange(-158, -154, .2), resolution='10m',
                     lat_lines=np.arange(69, 72, .1), projection=projection,
                     fig=fig, lat_0=csapr_lat,
                     lon_0=csapr_lon)

g = Geod(ellps='sphere')
lon = csapr_lon
lat = csapr_lat
rng = 1000 *25

lon2, lat2, _ = g.fwd(lon, lat, az, rng)
plt.plot([csapr_lon, lon2], [csapr_lat, lat2], transform=ccrs.Geodetic(),c='r',lw=2)
display.plot_point(csapr_lon, csapr_lat,c='r')
fig.patch.set_facecolor('white')
fig.tight_layout()
# Out:
# 201928
# (19, 201831.0)

# %%
print(radar.latitude['data'][0])
# Out:
# 29.471900939941406

# %% [markdown]
# ## Load lightning to plot with RHIs (incomplete)

# %%
import sys
#sys.path.append("./LMAinterceptRHI/")
sys.path.append("./TRACER-PAWS-NEXRAD-LMA/notebooks/LMAinterceptRHI/")
# Adapted functions from LMAinterceptRHI
from radarlma2local import geo_to_tps
from ortho_proj import rot_mat_lma, close_sources, closest_pt_radarloc
from radar_processing import r_z_centers_edges_mesh
from interp_funcs import centers_to_edges_1d, coords_2d

# %%
from datetime import datetime, date, time, timedelta

# %%
import xarray as xr

# %%
#..This is the main plotting routine
#..
maxx = 25
maxz = 12
#for idx in [236,]:
for idx in csapr_idx1:
    fname = june17_csapr_files[idx]
    #..
    radar = pyart.io.read(testpath+fname[-36:-3]+'_proc.nc')
    
    #radar = pyart.io.read(csapr_file[idx])
    print('Radar scan type: ' + radar.scan_type)

    # -- Get radar time
    d = date(int(radar.time['units'][14:18]),int(radar.time['units'][19:21]),int(radar.time['units'][22:24]))
    t = time(int(radar.time['units'][25:27]),int(radar.time['units'][28:30]),int(radar.time['units'][31:33]))
    radar_time = datetime.combine(d,t)
    print(radar_time)
    
    # -- Radar scan processing
    RZ_centers, RZ_edges = r_z_centers_edges_mesh(radar, 0)
    r_c = RZ_centers[:,:,0]
    z_c = RZ_centers[:,:,1]
    r_e = RZ_edges[:,:,0]
    z_e = RZ_edges[:,:,1]

    # Radar shape
    # -- To filter VHF sources out of the radar scan domain
    # --- Create the polygon: all ranges, lowest and highest elevation
    from shapely.geometry import Polygon, Point, MultiPoint
    scan_poly = Polygon(np.append(np.append(RZ_edges[-1, :-1],RZ_edges[0, :-1], axis = 0), RZ_edges[:, - 1], axis = 0))
    # scan_poly
    
    # Read lma file
    lightning_file = './LYLOUT_220617_000000_86400_map500m.nc'
    lma_data = xr.open_dataset(lightning_file)
    # lma_data.event_time.values = pd.to_datetime(lma_data.event_time.values.astype('M8[us]')).to_pydatetime()

    # Filter time and altitude
    seconds = 30
    sources = (lma_data.event_altitude < 18e3) & (abs( (np.datetime64(radar_time) - lma_data.event_time)/ np.timedelta64(1, 's') ) < seconds) 
    subset = lma_data[{'number_of_events': sources}]

    flashes_ids = np.unique(subset.event_parent_flash_id).astype(int)
    print(f'{len(flashes_ids)} flashes ids within {2*seconds} seconds.')

    # Select events info for individual flash id ('number_of_events' dimension)
    nid = 64
    one_id = lma_data.event_parent_flash_id == flashes_ids[nid]
    flash_events = lma_data[{'number_of_events': one_id}]

    # Filter data (stations > 5, chi2 < 2)
    filter_events = (flash_events.event_chi2 < 2) & (flash_events.event_stations > 5)
    filter_events
    filtered_flash = flash_events[{'number_of_events':filter_events}]

    # Only one flash events info in the dataset
    all_dims = dict(filtered_flash.dims)
    all_dims.pop('number_of_events') #all dims will no longer have 'number of flashes’
    one_flash = filtered_flash.drop_dims(all_dims.keys())
    one_flash
    
    # -- Initialize coordinate systems
    ctrlat, ctrlon, ctralt = radar.latitude['data'][0], radar.longitude['data'][0], radar.altitude['data'][0]
    geo = GeographicSystem()
    tps = TangentPlaneCartesianSystem(ctrlat, ctrlon, ctralt)
    rcs = RadarCoordinateSystem(ctrlat, ctrlon, ctralt)

    # --- Orthogonal projection/ Matrix Rotation of the LF sources
    Xlma,Ylma,Zlma = geo_to_tps(one_flash, radar)   # Filter does not have altitude
    XYZlma = np.column_stack((Xlma, Ylma, Zlma))
    lma_file_ortho = rot_mat_lma(radar, XYZlma, -1)  # -1 for counterclockwise

    # 1st STEP
    # -- Find and store sources within a certain ds distance
    ds = 1000 # m threshold
    r_cls, z_cls, y_min = close_sources(r_c, z_c, lma_file_ortho, ds)
    # -- Selected LMA sources inside the radar scan
    lma_shp = MultiPoint(tuple(np.vstack((r_cls, z_cls)).transpose()))
    R_cls = [] 
    Z_cls = []
    Y_min = []
    for i in np.arange(len(r_cls)):
        if scan_poly.contains(lma_shp[i]) == True:
            R_cls.append(np.asarray(lma_shp[i].coords[0])[0])
            Z_cls.append(np.asarray(lma_shp[i].coords[0])[1])
            Y_min.append(y_min[i])
    R_cls = np.asarray(R_cls)
    Z_cls = np.asarray(Z_cls)
    Y_min = np.asarray(Y_min)
    
    # ASSUME Y = 0 - real interception
    int_point1 = [np.array([R_cls[i], 0 , Z_cls[i]]) for i in np.arange(R_cls.size)]

    # 2o STEP
    # Transform from Rotationed Coordinate system Tangent Plane to Tangent Plan (rotates clockwise = 1)
    int_point2 = rot_mat_lma(radar, int_point1, 1)

    # 3o STEP
    # Tangent Plan to ECEF
    int_point3 = [tps.fromLocal(int_point2[i,:][:,None]) for i in np.arange(R_cls.size)]

    # 4o STEP
    # Transform from ECEF to Radar Coordinate System
    int_point4 = [rcs.fromECEF(int_point3[i][0],int_point3[i][1],int_point3[i][2]) for i in np.arange(R_cls.size)]

    # 5o STEP
    # Find closest point to RHI - Elevation and Range
    cls_r_idx = [closest_pt_radarloc(radar, int_point4[i])[0]  for i in np.arange(R_cls.size)]    # Radius index
    cls_az_idx = [closest_pt_radarloc(radar, int_point4[i])[1]  for i in np.arange(R_cls.size)]   # Azimuth index
    cls_elev_idx = [closest_pt_radarloc(radar, int_point4[i])[2]  for i in np.arange(R_cls.size)] # Elevation index

    # -- For plots below
    # -- Selecting coordinates and values for images below
    sel = [int(radar.sweep_start_ray_index['data'][0]), 
           int(radar.sweep_end_ray_index['data'][0])]
    values = np.ma.getdata(radar.fields['reflectivity']['data'][sel[0] : sel[1]+1, :])
    values[np.where(values < -10)] = 'nan'
    re = r_e[sel[0]: sel[1]+2]
    ze = z_e[sel[0]: sel[1]+2]
    
    fig = plt.figure(figsize=(12, 8), dpi=180)
    ax1 = fig.add_subplot(111)
    cs = ax1.pcolormesh(re/1000, ze/1000, values, vmin = 0, vmax = 50, 
                        cmap = pcm.LangRainbow12)
    llma = plt.scatter(R_cls/1000,  Z_cls/1000, c = abs(Y_min), 
                       edgecolor = 'black', cmap = 'Reds_r', marker = "X", 
                       s = 200, alpha = 0.5, vmin = 0, vmax = ds)
    # plt.xlim(0,120)
    plt.ylim(0,15)

    # -- cbar
    cb_ax = fig.add_axes([1.01, 0.13, 0.02, 0.75])
    cbar = fig.colorbar(cs, cax=cb_ax)
    cbar.set_label('Reflectivity (dBZ)', size=15)
    cbar.ax.tick_params(labelsize=11)

    llma_ax = fig.add_axes([0.92, 0.13, 0.02, 0.75])
    cbar2 = fig.colorbar(llma, cax=llma_ax)
    cbar2.set_label('Orthogonal Distance (m)', size=15)
    cbar2.ax.tick_params(labelsize=11)

    fig.text(0.55, 0.9,radar_time.strftime("%d %B %Y %H:%M:%S") + 
             f' - VHF sources within {ds} m from the RHI scan', 
             va='center', ha='center', fontsize = 15)
    fig.text(0.5, 0.05, 'Distance from radar (km)', va='center', 
             ha='center', fontsize = 15)
    fig.text(0.09, 0.5, 'Distance above radar (km)', va='center', 
             ha='center', rotation='vertical', fontsize = 15)
# Out:
# Radar scan type: rhi
# 2022-06-17 20:15:05
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     193         try:
# --> 194             dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     195         except (KeyError, OutOfBoundsDatetime, OverflowError):
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     145     delta, ref_date = _unpack_netcdf_time_units(units)
# --> 146     delta = _netcdf_to_numpy_timeunit(delta)
#     147     try:
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in _netcdf_to_numpy_timeunit(units)
#      52         "days": "D",
# ---> 53     }[units]
#      54
#
# KeyError: 'nanoseconds'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#     112     try:
# --> 113         result = decode_cf_datetime(example_value, units, calendar, use_cftime)
#     114     except Exception:
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     196             dates = _decode_datetime_with_cftime(
# --> 197                 flat_num_dates.astype(float), units, calendar
#     198             )
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in _decode_datetime_with_cftime(num_dates, units, calendar)
#     133     return np.asarray(
# --> 134         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#     135     )
#
# cftime/_cftime.pyx in cftime._cftime.num2date()
#
# cftime/_cftime.pyx in cftime._cftime._dateparse()
#
# ValueError: units must be one of 'seconds', 'minutes', 'hours' or 'days' (or singular version of these), got 'nanoseconds'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e7078eb01e82> in <module>
#      34     # Read lma file
#      35     lightning_file = './LYLOUT_220617_000000_86400_map500m.nc'
# ---> 36     lma_data = xr.open_dataset(lightning_file)
#      37     # lma_data.event_time.values = pd.to_datetime(lma_data.event_time.values.astype('M8[us]')).to_pydatetime()
#      38
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     573
#     574     with close_on_error(store):
# --> 575         ds = maybe_decode_store(store, chunks)
#     576
#     577     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/backends/api.py in maybe_decode_store(store, chunks)
#     477             drop_variables=drop_variables,
#     478             use_cftime=use_cftime,
# --> 479             decode_timedelta=decode_timedelta,
#     480         )
#     481
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     596         drop_variables=drop_variables,
#     597         use_cftime=use_cftime,
# --> 598         decode_timedelta=decode_timedelta,
#     599     )
#     600     ds = Dataset(vars, attrs=attrs)
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/conventions.py in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     498             stack_char_dim=stack_char_dim,
#     499             use_cftime=use_cftime,
# --> 500             decode_timedelta=decode_timedelta,
#     501         )
#     502         if decode_coords:
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/conventions.py in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     338         var = times.CFTimedeltaCoder().decode(var, name=name)
#     339     if decode_times:
# --> 340         var = times.CFDatetimeCoder(use_cftime=use_cftime).decode(var, name=name)
#     341
#     342     dimensions, data, attributes, encoding = variables.unpack_for_decoding(var)
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in decode(self, variable, name)
#     461             units = pop_to(attrs, encoding, "units")
#     462             calendar = pop_to(attrs, encoding, "calendar")
# --> 463             dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
#     464             transform = partial(
#     465                 decode_cf_datetime,
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/xarray/coding/times.py in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#     121             "if it is not installed."
#     122         )
# --> 123         raise ValueError(msg)
#     124     else:
#     125         dtype = getattr(result, "dtype", np.dtype("object"))
#
# ValueError: unable to decode time units 'nanoseconds since 2022-06-17 00:00:00.677060386' with "calendar 'proleptic_gregorian'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.

# %%
import sys
sys.path.append("./LMAinterceptRHI/")
# Functions
from radarlma2local import geo_to_tps
from select_lma import one_flash
from plot_radar import plot_locs_lma_rhi, plot_RHI_EDR_panel,plot_EDR_dVR, plot_sources_interp
from ortho_proj import rot_mat_lma, closest_pt_radarloc, close_sources
from radar_processing import dealias_range_elev_derivatives, r_z_centers_edges_mesh
from interp_funcs import centers_to_edges_1d, coords_2d
from interp_funcs import oban, barnes, weighted_mean, weighted_std, interp_avg_std

# %%
# -- LIGHTNING
lma_base = './LYLOUT_220604_190000_18000_map500m.nc'
lma = LMAh5File(lma_base)
events, flashes = lma.data_for_table(lma.table_names[0])
flashes = pd.DataFrame(flashes)
events = pd.DataFrame(events)
events = events[events.alt < 16000.][events.stations > 5][events.chi2 < 5.]
potential = events
# Out:
# ---------------------------------------------------------------------------
# NoSuchNodeError                           Traceback (most recent call last)
# <ipython-input-189-ccde3d04dd4a> in <module>
#       1 # -- LIGHTNING
#       2 lma_base = './LYLOUT_220604_190000_18000_map500m.nc'
# ----> 3 lma = LMAh5File(lma_base)
#       4 events, flashes = lma.data_for_table(lma.table_names[0])
#       5 flashes = pd.DataFrame(flashes)
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/lmatools-0.6a0-py3.6.egg/lmatools/io/LMA_h5_file.py in __init__(self, filename, min_points)
#     165         self.h5 = tables.open_file(filename)
#     166         self.min_points = min_points
# --> 167         table_names = list(self.h5.root.events._v_children.keys())
#     168         start_times = [datetime(*getattr(self.h5.root.events,
#     169                                     the_table).attrs['start_time']) for
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/tables/group.py in __getattr__(self, name)
#     834             self._g_add_children_names()
#     835             return self.__dict__[name]
# --> 836         return self._f_get_child(name)
#     837
#     838     def __setattr__(self, name, value):
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/tables/group.py in _f_get_child(self, childname)
#     706         self._g_check_open()
#     707
# --> 708         self._g_check_has_child(childname)
#     709
#     710         childpath = join_path(self._v_pathname, childname)
#
# ~/miniconda3/envs/cmac_env/lib/python3.6/site-packages/tables/group.py in _g_check_has_child(self, name)
#     393             raise NoSuchNodeError(
#     394                 "group ``%s`` does not have a child named ``%s``"
# --> 395                 % (self._v_pathname, name))
#     396         return node_type
#     397
#
# NoSuchNodeError: group ``/`` does not have a child named ``events``

# %%
# -- RADAR
radar = pyart.io.read('houcsapr2cfrS2.a1.20220604.221847.nc')
# -- Creating EDR field parameter
gate_spacing = radar.range['meters_between_gates']/1000.
beamwidth = radar.instrument_parameters['radar_beam_width_h']['data'][0]
#pytda.calc_turb_rhi(radar, verbose = False, use_ntda=False, beamwidth=beamwidth, gate_spacing=gate_spacing)

# # -- Adding dealias velocity, dVRdr, dVRde fields to radar file
# import warnings
# warnings.simplefilter("ignore")
# radar = dealias_range_elev_derivatives(radar)

# arq_tur = './radar/turb_' + os.path.split(arq_ka)[1]
# # .nc export
# try:
#     os.remove(arq_tur)
# except OSError:
#     pass
# pyart.io.cfradial.write_cfradial(arq_tur, radar,format='NETCDF4')

# -- Get radar time
d = date(int(radar.time['units'][14:18]),int(radar.time['units'][19:21]),int(radar.time['units'][22:24]))
t = time(int(radar.time['units'][25:27]),int(radar.time['units'][28:30]),int(radar.time['units'][31:33]))
radar_time = datetime.combine(d,t)
print(radar_time)


# -- Radar scan processing
#data = xr.open_dataset(arq_tur)
RZ_centers, RZ_edges = r_z_centers_edges_mesh(radar, 0)
# -- WITH THIS I'M ONLY TAKING 1 SWEEP IF I WANT MORE OR ALL I UNCOMMENT THE BELLOW LINES BUT IT TAKES A LONG TIME
# for sweep_idx in np.arange(1, len(data.sweep_start_ray_index)):
#     centers, edges = r_z_centers_edges_mesh(data, sweep_idx)
#     RZ_centers = np.append(RZ_centers, centers, axis = 0)
#     RZ_edges = np.append(RZ_edges, edges, axis = 0)
r_c = RZ_centers[:,:,0]
z_c = RZ_centers[:,:,1]
r_e = RZ_edges[:,:,0]
z_e = RZ_edges[:,:,1]

# -- To filter VHF sources out of the radar scan domain
# --- Create the polygon: all ranges, lowest and highest elevation
# --- ~ 23 km (IDX 221), 23.5 km (IDX 165)range all elevations
# RZ_edges[:, - 165]
from shapely.geometry import Polygon, Point, MultiPoint
scan_poly = Polygon(np.append(np.append(RZ_edges[-1, :-221],RZ_edges[0, :-221], axis = 0), RZ_edges[:, - 221], axis = 0))

# -- FLASH
# --- Select the flash #k
flash = one_flash(potential, flashes_id[k])
flash = flash.sort_values(by=['time'])

# --- Orthogonal projection/ Matrix Rotation of the LF sources
Xlma,Ylma,Zlma = geo_to_tps(flash, radar)
XYZlma = np.column_stack((Xlma, Ylma, Zlma))
lma_file_ortho = rot_mat_lma(radar, XYZlma, -1)

# -- Initialize coordinate systems
ctrlat, ctrlon, ctralt = data.latitude.values, data.longitude.values, data.altitude.values
geo = GeographicSystem()
tps = TangentPlaneCartesianSystem(ctrlat, ctrlon, ctralt)
rcs = RadarCoordinateSystem(ctrlat, ctrlon, ctralt)

# -- First source location in the cross section
alt_lma_init = flashes.init_alt[flashes.flash_id == flash.flash_id.values[0]].values[0]
lat_lma_init = flashes.init_lat[flashes.flash_id == flash.flash_id.values[0]].values[0]
lon_lma_init = flashes.init_lon[flashes.flash_id == flash.flash_id.values[0]].values[0]
m = rot_mat_lma(radar, np.column_stack(tps.toLocal(np.vstack(geo.toECEF(lon_lma_init, lat_lma_init, alt_lma_init)))), -1)[0]
X1, Y1, Z1 = m[0], m[1], m[2]

# 1st STEP
# -- Find and store sources within a certain distance
ds = 100 # threshold
r_cls, z_cls, y_min = close_sources(r_c, z_c, lma_file_ortho, ds)
# -- Selected LMA sources inside the radar scan
lma_shp = MultiPoint(tuple(np.vstack((r_cls, z_cls)).transpose()))
R_cls = [] 
Z_cls = []
Y_min = []
for i in np.arange(len(r_cls)):
    if scan_poly.contains(lma_shp[i]) == True:
        R_cls.append(np.asarray(lma_shp[i].coords[0])[0])
        Z_cls.append(np.asarray(lma_shp[i].coords[0])[1])
        Y_min.append(y_min[i])
R_cls = np.asarray(R_cls)
Z_cls = np.asarray(Z_cls)
Y_min = np.asarray(Y_min)
